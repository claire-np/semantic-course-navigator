# %% [markdown]
# # 📘 Topic Search & Dataset Normalization Pipeline
#
# This notebook implements the preprocessing and normalization pipeline that feeds the semantic search engine and the learning-path recommender.
# It converts the raw Udemy Business marketplace export into a unified, analytics-ready dataset with:
#
# - Cleaned and standardized text fields
# - Normalized numeric metadata
# - Consolidated semantic fields for embedding generation
# - Consistent schema required for FAISS indexing and SBERT-based retrieval.
#
# The final output of this notebook is `unified_courses_v1.csv`, which serves as the canonical dataset for the embedding pipeline and the downstream vector search system.

# %% [markdown]
# ### 1. Dataset Loading & Initial Profiling
# Load the raw marketplace dump and examine schema completeness, missing-value patterns, categorical cardinality, and numeric distributions.
# This step validates the integrity of the raw export before downstream normalization.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("raw_marketplace.csv")
print("Loaded dataset successfully.")
# Out:
# Loaded dataset successfully.

# %%
df.head()
# Out:
#    courseid                                       course_title  \
# 0   4918126                        Principles of Secure Coding
# 1   4896784               No-Code and No-Math Machine Learning
# 2   4896268       How to give and receive feedback effectively
# 3   4879342  Prepare for the Salesforce Certified Associate...
# 4   4878666  Google Cloud Machine Learning Engineer Certifi...
#
#   instructor_title       category                    subcategory  \
# 0  Chris B Behrens    Development           Software Engineering
# 1   Jones Granatyr   Data Science              Math & Statistics
# 2     Jamal Lazaar  Communication  Fundamentals of Communication
# 3  Emily Call, MBA  IT Operations              IT Certifications
# 4     Dan Sullivan  IT Operations              IT Certifications
#
#                                           course_url  avg_rating_90d  \
# 0  https://www.udemy.com/principles-of-secure-coding            4.48
# 1  https://www.udemy.com/no-code-no-math-machine-...            4.75
# 2    https://www.udemy.com/give-and-receive-feedback            4.64
# 3  https://www.udemy.com/prepare-for-the-salesfor...            4.47
# 4  https://www.udemy.com/google-cloud-machine-lea...            4.29
#
#    num_rating_90d  num_rating_all_time  enrollments  hrs_of_content  \
# 0            1590                 6299          878          3.3886
# 1              10                   88         1455          5.1229
# 2             286                 1490         4973          1.1391
# 3             223                 2515         1092          3.9997
# 4             121                  664         1716          5.2511
#
#    duration_hours course_mapping_keywords  rnk_enrollments  \
# 0             2.0                     NaN             4880
# 1             0.0        Machine Learning              310
# 2             0.0                     NaN             4153
# 3             1.0                     NaN             4840
# 4             0.0        Machine Learning              306
#
#                                          topic_title  topic_id
# 0                                Generic Programming    5930.0
# 1                                   Machine Learning    6594.0
# 2                             Interpersonal Feedback   89930.0
# 3                     Salesforce Certified Associate  157870.0
# 4  Google Cloud Professional Machine Learning Eng...  156700.0

# %%
df.info()
df.describe(include='all').T
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26232 entries, 0 to 26231
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   courseid                 26232 non-null  int64
#  1   course_title             26232 non-null  object
#  2   instructor_title         26232 non-null  object
#  3   category                 26232 non-null  object
#  4   subcategory              26232 non-null  object
#  5   course_url               26232 non-null  object
#  6   avg_rating_90d           26232 non-null  float64
#  7   num_rating_90d           26232 non-null  int64
#  8   num_rating_all_time      26232 non-null  int64
#  9   enrollments              26232 non-null  int64
#  10  hrs_of_content           25938 non-null  float64
#  11  duration_hours           26229 non-null  float64
#  12  course_mapping_keywords  7321 non-null   object
#  13  rnk_enrollments          26232 non-null  int64
#  14  topic_title              26150 non-null  object
#  15  topic_id                 26150 non-null  float64
# dtypes: float64(4), int64(5), object(7)
# memory usage: 3.2+ MB
#                            count unique  \
# courseid                 26232.0    NaN
# course_title               26232   7804
# instructor_title           26232   2920
# category                   26232     32
# subcategory                26232    195
# course_url                 26232   7510
# avg_rating_90d           26232.0    NaN
# num_rating_90d           26232.0    NaN
# num_rating_all_time      26232.0    NaN
# enrollments              26232.0    NaN
# hrs_of_content           25938.0    NaN
# duration_hours           26229.0    NaN
# course_mapping_keywords     7321     59
# rnk_enrollments          26232.0    NaN
# topic_title                26150   2178
# topic_id                 26150.0    NaN
#
#                                                                top  freq  \
# courseid                                                       NaN   NaN
# course_title                                   Java Multithreading    49
# instructor_title                                      Simon Sez IT   235
# category                                               Development  6814
# subcategory                                        Web Development  1989
# course_url               https://www.udemy.com/java-multithreading    49
# avg_rating_90d                                                 NaN   NaN
# num_rating_90d                                                 NaN   NaN
# num_rating_all_time                                            NaN   NaN
# enrollments                                                    NaN   NaN
# hrs_of_content                                                 NaN   NaN
# duration_hours                                                 NaN   NaN
# course_mapping_keywords                           Machine Learning  1150
# rnk_enrollments                                                NaN   NaN
# topic_title                                                 Python   340
# topic_id                                                       NaN   NaN
#
#                                    mean             std     min       25%  \
# courseid                 1689901.771005  1260061.053054  8139.0  735420.0
# course_title                        NaN             NaN     NaN       NaN
# instructor_title                    NaN             NaN     NaN       NaN
# category                            NaN             NaN     NaN       NaN
# subcategory                         NaN             NaN     NaN       NaN
# course_url                          NaN             NaN     NaN       NaN
# avg_rating_90d                 4.527636        0.127014    4.25      4.45
# num_rating_90d               248.452005      819.029425     9.0      25.0
# num_rating_all_time         5735.749733    16164.598722     9.0     658.0
# enrollments               110369.533089   237066.313468    30.0  12628.25
# hrs_of_content                12.537945       79.418866  0.2437    2.7691
# duration_hours                 0.589653        0.796813     0.0       0.0
# course_mapping_keywords             NaN             NaN     NaN       NaN
# rnk_enrollments             1719.970037     1630.424679     1.0     94.75
# topic_title                         NaN             NaN     NaN       NaN
# topic_id                   29839.450134    127140.56258  4274.0    5880.0
#
#                                50%        75%        max
# courseid                 1320528.0  2490968.0  4918126.0
# course_title                   NaN        NaN        NaN
# instructor_title               NaN        NaN        NaN
# category                       NaN        NaN        NaN
# subcategory                    NaN        NaN        NaN
# course_url                     NaN        NaN        NaN
# avg_rating_90d                4.52       4.61        5.0
# num_rating_90d                69.0      189.0    29558.0
# num_rating_all_time         1656.0    4607.25   499646.0
# enrollments                39701.0   107847.5  5334056.0
# hrs_of_content                5.51  11.664575  2300.9314
# duration_hours                 0.0        1.0        3.0
# course_mapping_keywords        NaN        NaN        NaN
# rnk_enrollments             1325.0    3073.25     5459.0
# topic_title                    NaN        NaN        NaN
# topic_id                    7336.0    11778.0  2183129.0

# %% [markdown]
# ### 2. Text-Field Standardization
# Normalize all text fields to ensure consistent input to the embedding model:
# - cast to string,
# - trim whitespace,
# - replace nulls with empty strings,
# preventing tokenization errors and inconsistent semantic representations.

# %%
text_cols = [
    'courseid', 'course_title', 'instructor_title',
    'category', 'subcategory', 'course_url',
    'course_mapping_keywords', 'topic_title'
]
for col in text_cols:
    df[col] = df[col].astype(str).str.strip().fillna("")

# %% [markdown]
# ### 3. Numeric Field Normalization
# Unify numeric schema by standardizing column names and coercing inconsistent types.
# `duration_hours` and `topic_id` are cleaned to ensure stable downstream use in ranking logic and filtering operations.

# %%
df = df.drop(columns=['duration_hours'])
df = df.rename(columns={'hrs_of_content': 'duration_hours'})
df[['duration_hours']].describe()
# Out:
#        duration_hours
# count    25938.000000
# mean        12.537945
# std         79.418866
# min          0.243700
# 25%          2.769100
# 50%          5.510000
# 75%         11.664575
# max       2300.931400

# %%
df['topic_id'] = pd.to_numeric(df['topic_id'], errors='coerce')
df['topic_id'] = df['topic_id'].fillna(-1)
df['topic_id'] = df['topic_id'].astype(int)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26232 entries, 0 to 26231
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   courseid                 26232 non-null  object
#  1   course_title             26232 non-null  object
#  2   instructor_title         26232 non-null  object
#  3   category                 26232 non-null  object
#  4   subcategory              26232 non-null  object
#  5   course_url               26232 non-null  object
#  6   avg_rating_90d           26232 non-null  float64
#  7   num_rating_90d           26232 non-null  int64
#  8   num_rating_all_time      26232 non-null  int64
#  9   enrollments              26232 non-null  int64
#  10  duration_hours           25938 non-null  float64
#  11  course_mapping_keywords  26232 non-null  object
#  12  rnk_enrollments          26232 non-null  int64
#  13  topic_title              26232 non-null  object
#  14  topic_id                 26232 non-null  int64
# dtypes: float64(2), int64(5), object(8)
# memory usage: 3.0+ MB

# %% [markdown]
# ### 4. Embedding-Text Construction
# Create a consolidated semantic field combining course title, category, subcategory, topic, and curated keywords.
# This engineered field is the input to SBERT/GTE for vector encoding and significantly improves retrieval quality.

# %%
def make_embedding_text(row):
    parts = []
    parts.append(str(row['course_title']))
    parts.append(str(row['category']))
    parts.append(str(row['subcategory']))

    if row['topic_title'].strip() != "":
        parts.append(str(row['topic_title']))
    if row['course_mapping_keywords'].strip() != "":
        parts.append(str(row['course_mapping_keywords']))
    return " | ".join(parts)

df['embedding_text'] = df.apply(make_embedding_text, axis=1)
df[['course_title','embedding_text']].head(10)
# Out:
#                                         course_title  \
# 0                        Principles of Secure Coding
# 1               No-Code and No-Math Machine Learning
# 2       How to give and receive feedback effectively
# 3  Prepare for the Salesforce Certified Associate...
# 4  Google Cloud Machine Learning Engineer Certifi...
# 5  Google Cloud Machine Learning Engineer Certifi...
# 6  Thriving in a Hybrid Environment: Tactics for ...
# 7  Thriving in a Hybrid Environment: Tactics for ...
# 8  Thriving in a Hybrid Environment: Tactics for ...
# 9  Artificial Intelligence AI Marketing to Grow y...
#
#                                       embedding_text
# 0  Principles of Secure Coding | Development | So...
# 1  No-Code and No-Math Machine Learning | Data Sc...
# 2  How to give and receive feedback effectively |...
# 3  Prepare for the Salesforce Certified Associate...
# 4  Google Cloud Machine Learning Engineer Certifi...
# 5  Google Cloud Machine Learning Engineer Certifi...
# 6  Thriving in a Hybrid Environment: Tactics for ...
# 7  Thriving in a Hybrid Environment: Tactics for ...
# 8  Thriving in a Hybrid Environment: Tactics for ...
# 9  Artificial Intelligence AI Marketing to Grow y...

# %% [markdown]
# ### 5. Export Clean Unified Dataset
# Export the canonical dataset used by:
# - the SBERT embedding pipeline,
# - FAISS vector index builder,
# - semantic search engine,
# - learning-path generator.
#
# This file represents the fully normalized and embedding-ready version of the Udemy catalog.

# %%
df.to_csv("unified_courses_v1.csv", index=False)

# %%
print("Number of categories:", df['category'].nunique())
print("Number of subcategories:", df['subcategory'].nunique())
print("Number of topics:", df['topic_title'].nunique())

print("\nSample categories:")
print(df['category'].value_counts().head(10))

print("\nSample topics:")
print(df['topic_title'].value_counts().head(15))
# Out:
# Number of categories: 32
# Number of subcategories: 195
# Number of topics: 2179
#
# Sample categories:
# category
# Development                6814
# IT Operations              3319
# Data Science               1989
# Personal Development       1958
# Leadership & Management    1298
# Finance & Accounting       1081
# Marketing                   934
# Productivity                795
# Cloud Computing             774
# Design Tools                772
# Name: count, dtype: int64
#
# Sample topics:
# topic_title
# Python                       340
# Java                         274
# Excel                        242
# Leadership                   188
# JavaScript                   180
# SQL                          137
# Project Management           136
# Agile                        134
# Amazon AWS                   130
# Data Analysis                123
# Business Analysis            121
# C# (programming language)    111
# Presentation Skills          109
# Sales Skills                 106
# Management Skills            105
# Name: count, dtype: int64

# %%
def find_topics(keyword, top_n=20):
    keyword = keyword.lower()
    mask = df['topic_title'].str.lower().str.contains(keyword)
    return df.loc[mask, 'topic_title'].value_counts().head(top_n)
# Example:
find_topics("python")
# Out:
# topic_title
# Python                                            340
# Certified Entry-Level Python Programmer (PCEP)     10
# Python Network Programming                          7
# MicroPython                                         4
# Python GUI                                          2
# Python Hacking                                      2
# Python Scripting                                    2
# Name: count, dtype: int64

# %%
def search_by_title(keyword, top_n=20):
    keyword = keyword.lower()
    mask = df['course_title'].str.lower().str.contains(keyword)
    results = df.loc[mask, [
        'courseid', 'course_title', 'category', 'subcategory',
        'avg_rating_90d', 'num_rating_all_time', 'enrollments',
        'duration_hours'
    ]].copy()

    # sort by rating + review num
    results = results.sort_values(
        by=['avg_rating_90d', 'num_rating_all_time', 'enrollments'],
        ascending=[False, False, False]
    )

    return results.head(top_n)

# test:
search_by_title("python").head(10)
# Out:
#       courseid                                       course_title  \
# 18318  3663114           Mastering 4 critical SKILLS using Python
# 18319  3663114           Mastering 4 critical SKILLS using Python
# 1500   3663114           Mastering 4 critical SKILLS using Python
# 1501   3663114           Mastering 4 critical SKILLS using Python
# 21765  1647776  Python 3: Deep Dive (Part 2 - Iterators, Gener...
# 1467   3687702          Short Programming intro in Python and C++
# 18289  3687702          Short Programming intro in Python and C++
# 3542   2358038  Learn 100+ Python Pattern Printing Programs In...
# 20361  2358038  Learn 100+ Python Pattern Printing Programs In...
# 4921   1647776  Python 3: Deep Dive (Part 2 - Iterators, Gener...
#
#             category            subcategory  avg_rating_90d  \
# 18318  IT Operations      IT Certifications            4.93
# 18319  IT Operations      IT Certifications            4.93
# 1500   IT Operations      IT Certifications            4.91
# 1501   IT Operations      IT Certifications            4.91
# 21765    Development  Programming Languages            4.85
# 1467     Development  Programming Languages            4.85
# 18289    Development  Programming Languages            4.85
# 3542     Development  Programming Languages            4.85
# 20361    Development  Programming Languages            4.85
# 4921     Development  Programming Languages            4.84
#
#        num_rating_all_time  enrollments  duration_hours
# 18318                  890         8987         28.5329
# 18319                  890         8987         28.5329
# 1500                   900         8930         28.5329
# 1501                   900         8930         28.5329
# 21765                 2526        87724         36.1577
# 1467                   296         5423          9.2061
# 18289                  296         5417          9.2061
# 3542                   179        16144         46.4227
# 20361                  178        16166         46.4227
# 4921                  2560        87370         36.1577

# %%
def search_by_topic(topic_name, top_n=20):
    # exact match, case-insensitive
    topic_name_lower = topic_name.lower()
    mask = df['topic_title'].str.lower() == topic_name_lower

    topic_df = df.loc[mask, [
        'courseid', 'course_title', 'category', 'subcategory',
        'avg_rating_90d', 'num_rating_all_time', 'enrollments',
        'duration_hours'
    ]].copy()

    if topic_df.empty:
        print("No course found for topic:", topic_name)
        return topic_df

    topic_df = topic_df.sort_values(
        by=['avg_rating_90d', 'num_rating_all_time', 'enrollments'],
        ascending=[False, False, False]
    )

    return topic_df.head(top_n)

# %%
search_by_topic("Machine Learning")
# Out:
#       courseid                                       course_title  \
# 17977  3914960  Machine Learning for Data Analysis: Classifica...
# 1657   3565567              Machine Learning with Imbalanced Data
# 16844  4896784               No-Code and No-Math Machine Learning
# 1147   3914960  Machine Learning for Data Analysis: Classifica...
# 5200   1548436             Feature Selection for Machine Learning
# 5234   1533128  Clustering & Classification With Machine Learn...
# 6380   1221664                      Applied Machine Learning in R
# 23259  1221664                      Applied Machine Learning in R
# 1      4896784               No-Code and No-Math Machine Learning
# 4263   1955654                   Machine Learning with Javascript
# 18477  3565567              Machine Learning with Imbalanced Data
# 1290   3802920   Hyperparameter Optimization for Machine Learning
# 21095  1955654                   Machine Learning with Javascript
# 18122  3802920   Hyperparameter Optimization for Machine Learning
# 24447   821726  Data Science and Machine Learning Bootcamp with R
# 22045  1548436             Feature Selection for Machine Learning
# 21956  1580888  Clustering & Classification With Machine Learn...
# 3065   2598770  Complete Machine Learning and Deep Learning Wi...
# 19883  2598770  Complete Machine Learning and Deep Learning Wi...
# 11223  1304050           Feature Engineering for Machine Learning
#
#            category         subcategory  avg_rating_90d  num_rating_all_time  \
# 17977  Data Science    Machine Learning            4.87                  464
# 1657   Data Science  Data Visualization            4.85                  717
# 16844  Data Science   Math & Statistics            4.85                   86
# 1147   Data Science    Machine Learning            4.80                  467
# 5200   Data Science    Machine Learning            4.75                 2143
# 5234   Data Science    Machine Learning            4.75                  367
# 6380    Development              DevOps            4.75                  258
# 23259   Development              DevOps            4.75                  256
# 1      Data Science   Math & Statistics            4.75                   88
# 4263   Data Science    Machine Learning            4.74                 3230
# 18477  Data Science  Data Visualization            4.74                  703
# 1290   Data Science    Machine Learning            4.72                  580
# 21095  Data Science    Machine Learning            4.71                 3196
# 18122  Data Science    Machine Learning            4.71                  560
# 24447  Data Science    Machine Learning            4.70                16662
# 22045  Data Science    Machine Learning            4.70                 2117
# 21956  Data Science    Machine Learning            4.70                  218
# 3065   Data Science    Machine Learning            4.70                  112
# 19883  Data Science    Machine Learning            4.70                  112
# 11223   Development        Data Science            4.68                 2790
#
#        enrollments  duration_hours
# 17977        12169          2.5146
# 1657         21900          9.1628
# 16844         1445          5.1229
# 1147         12121          2.5146
# 5200         62937          5.8295
# 5234          6029          6.0704
# 6380          1229          8.1795
# 23259         1223          8.1795
# 1             1455          5.1229
# 4263         71393         17.6790
# 18477        22059          9.2498
# 1290         22221          9.4026
# 21095        71399         17.6790
# 18122        22410          9.3993
# 24447       260918         17.7641
# 22045        63066          5.8262
# 21956         1534          8.1000
# 3065          1814          4.4186
# 19883         1807          4.4186
# 11223        88209         11.4517

# %%
find_topics("machine")
# Out:
# topic_title
# Machine Learning                                       99
# AWS Certified Machine Learning - Specialty             14
# Azure Virtual Machines                                  8
# Azure Machine Learning                                  5
# Google Cloud Professional Machine Learning Engineer     4
# Java Virtual Machine                                    3
# Supervised Machine Learning                             2
# Unsupervised Machine Learning                           2
# AutoML Automated Machine Learning                       2
# World Machine                                           2
# Name: count, dtype: int64

# %%
def print_top_courses_for_topic(topic_name, top_n=10):
    results = search_by_topic(topic_name, top_n=top_n)
    if results.empty:
        return
    
    display_cols = [
        'course_title', 'avg_rating_90d',
        'num_rating_all_time', 'enrollments', 'duration_hours'
    ]
    print(f"Top {top_n} courses for topic: {topic_name}\n")
    print(results[display_cols])

# test:
print_top_courses_for_topic("Machine Learning", top_n=5)
# Out:
# Top 5 courses for topic: Machine Learning
#
#                                             course_title  avg_rating_90d  \
# 17977  Machine Learning for Data Analysis: Classifica...            4.87
# 1657               Machine Learning with Imbalanced Data            4.85
# 16844               No-Code and No-Math Machine Learning            4.85
# 1147   Machine Learning for Data Analysis: Classifica...            4.80
# 5200              Feature Selection for Machine Learning            4.75
#
#        num_rating_all_time  enrollments  duration_hours
# 17977                  464        12169          2.5146
# 1657                   717        21900          9.1628
# 16844                   86         1445          5.1229
# 1147                   467        12121          2.5146
# 5200                  2143        62937          5.8295
