# %%
# !python3 -m pip install sentence-transformers
# !python3 -m pip install faiss-cpu
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sentence-transformers in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (5.1.2)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (4.57.3)
# Requirement already satisfied: tqdm in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: torch>=1.11.0 in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (2.8.0)
# Requirement already satisfied: scikit-learn in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (1.1.3)
# Requirement already satisfied: scipy in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (0.36.0)
# Requirement already satisfied: Pillow in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (11.3.0)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from sentence-transformers) (4.15.0)
# Requirement already satisfied: filelock in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (3.19.1)
# Requirement already satisfied: numpy>=1.17 in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.11.3)
# Requirement already satisfied: requests in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.7.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from torch>=1.11.0->sentence-transformers) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from requests->transformers<5.0.0,>=4.41.0->sentence-transformers) (2025.10.5)
# Requirement already satisfied: joblib>=1.0.0 in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from scikit-learn->sentence-transformers) (1.5.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: faiss-cpu in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (1.13.0)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /Users/phuonglinh39/Library/Python/3.9/lib/python/site-packages (from faiss-cpu) (25.0)

# %%
import pandas as pd
df = pd.read_csv("unified_courses_v1.csv")
print(df.shape)
# Out:
# (26232, 16)

# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# /Users/phuonglinh39/dsenv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
embeddings = model.encode(df['embedding_text'].tolist(), batch_size=64, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/410 [00:00<?, ?it/s]

# %%
import numpy as np

np.save("course_embeddings.npy", embeddings)
print("Saved course_embeddings.npy")
# Out:
# Saved course_embeddings.npy

# %%
import faiss
dimension = embeddings.shape[1]

index = faiss.IndexFlatL2(dimension)
index.add(embeddings)
print("Index size:", index.ntotal)
# Out:
# Index size: 26232

# %%
import faiss

faiss.write_index(index, "faiss_index.bin")
print("Saved faiss_index.bin")
# Out:
# Saved faiss_index.bin

# %%
def recommend_similar(title_query, k=10):
    query = title_query.lower()
    matches = df[df['course_title'].str.lower().str.contains(query)]
    
    if matches.empty:
        return "Course not found. Try using a shorter part of the course title."
    
    idx = matches.index[0]
    query_vec = embeddings[idx].reshape(1, -1)
    distances, indices = index.search(query_vec, k+1)
    results = df.iloc[indices[0][1:k+1]][[
        'course_title', 'category', 'subcategory',
        'avg_rating_90d', 'num_rating_all_time', 'enrollments'
    ]]
    
    return results

# %%
recommend_similar("Machine Learning for Data Analysis", k=5)
# Out:
#                                             course_title      category  \
# 17188  Machine Learning for Data Analysis: Unsupervis...   Development
# 1463   Machine Learning for Data Analysis: Data Profi...  Data Science
# 18284  Machine Learning for Data Analysis: Data Profi...  Data Science
# 1147   Machine Learning for Data Analysis: Classifica...  Data Science
# 17977  Machine Learning for Data Analysis: Classifica...  Data Science
#
#                          subcategory  avg_rating_90d  num_rating_all_time  \
# 17188  Database Design & Development            4.45                  735
# 1463                Machine Learning            4.54                 3702
# 18284               Machine Learning            4.57                 3587
# 1147                Machine Learning            4.80                  467
# 17977               Machine Learning            4.87                  464
#
#        enrollments
# 17188         6542
# 1463         22615
# 18284        22676
# 1147         12121
# 17977        12169

# %%
recommend_similar("Data Analysis", k=5)
# Out:
#                                             course_title      category  \
# 16878  Data Analysis with Python: NumPy & Pandas Mast...  Data Science
# 7247                Data Analysis with Pandas and Python  Data Science
# 13194               Data Analysis with Pandas and Python  Data Science
# 24122               Data Analysis with Pandas and Python  Data Science
# 7248                Data Analysis with Pandas and Python  Data Science
#
#       subcategory  avg_rating_90d  num_rating_all_time  enrollments
# 16878   Analytics            4.60                 1231        19310
# 7247    Analytics            4.63                21610       201688
# 13194   Analytics            4.62                18666       496727
# 24122   Analytics            4.65                21345       306630
# 7248    Analytics            4.63                21610       201688

# %%
recommend_similar("Machine Learning", k=5)
# Out:
#                                             course_title      category  \
# 16844               No-Code and No-Math Machine Learning  Data Science
# 6131   Data Science : Master Machine Learning Without...  Data Science
# 23002  Data Science : Master Machine Learning Without...  Data Science
# 6130   Data Science : Master Machine Learning Without...  Data Science
# 23003  Data Science : Master Machine Learning Without...  Data Science
#
#              subcategory  avg_rating_90d  num_rating_all_time  enrollments
# 16844  Math & Statistics            4.85                   86         1445
# 6131    Machine Learning            4.34                  966        38675
# 23002   Machine Learning            4.40                  951        38543
# 6130    Machine Learning            4.34                  966        38675
# 23003   Machine Learning            4.40                  951        38543

# %%
def embed_query(text):
    return model.encode([text])[0]

# %%
def semantic_search(query_text, k=10):
    # embed query
    query_vec = embed_query(query_text).reshape(1, -1)
    
    # FAISS search
    distances, indices = index.search(query_vec, k)
    
    # return human-readable table
    results = df.iloc[indices[0]][[
        'course_title', 'category', 'subcategory',
        'avg_rating_90d', 'num_rating_all_time', 'enrollments'
    ]].copy()
    
    results['score'] = distances[0]
    return results

# %%
semantic_search("machine learning", 5)
# Out:
#                                             course_title      category  \
# 1402   Complete Machine Learning 2024 A-Z™: 10 Real W...  Data Science
# 18227  Complete Machine Learning 2023 A-Z™: 10 Real W...  Data Science
# 10942  An Introduction to Machine Learning for Data E...   Development
# 5200              Feature Selection for Machine Learning  Data Science
# 22045             Feature Selection for Machine Learning  Data Science
#
#             subcategory  avg_rating_90d  num_rating_all_time  enrollments  \
# 1402   Machine Learning            4.33                  437        29167
# 18227  Machine Learning            4.55                  429        29289
# 10942      Data Science            4.42                 3058        88972
# 5200   Machine Learning            4.75                 2143        62937
# 22045  Machine Learning            4.70                 2117        63066
#
#           score
# 1402   0.754888
# 18227  0.780812
# 10942  0.794480
# 5200   0.813747
# 22045  0.813747

# %%
semantic_search("machine learning for finance", 5)
# Out:
#                                             course_title  \
# 12640  Python for Finance: Investment Fundamentals & ...
# 2331   Artificial Intelligence for Finance, Accountin...
# 19152  Artificial Intelligence for Finance, Accountin...
# 3751   Manage Finance Data with Python & Pandas: Uniq...
# 20576  Manage Finance Data with Python & Pandas: Uniq...
#
#                    category                    subcategory  avg_rating_90d  \
# 12640          Data Science                      Analytics            4.57
# 2331           Data Science               Machine Learning            4.52
# 19152          Data Science               Machine Learning            4.50
# 3751   Finance & Accounting  Financial Modeling & Analysis            4.50
# 20576  Finance & Accounting  Financial Modeling & Analysis            4.53
#
#        num_rating_all_time  enrollments     score
# 12640                25562       292189  0.673680
# 2331                  1543        32189  0.685297
# 19152                 1397        32142  0.685297
# 3751                   840        31628  0.697649
# 20576                  822        31620  0.697649

# %%
semantic_search("python for beginners", 5)
# Out:
#                              course_title     category            subcategory  \
# 25116  Python for Beginners with Examples  Development  Programming Languages
# 8231   Python for Beginners with Examples  Development  Programming Languages
# 14887  Python for Beginners with Examples  Development  Programming Languages
# 5703                 Python for beginners  Development  Programming Languages
# 10547                Python for beginners  Development  Programming Languages
#
#        avg_rating_90d  num_rating_all_time  enrollments     score
# 25116            4.37                 9662        10428  0.297954
# 8231             4.39                 9676        10349  0.297954
# 14887            4.35                 9424        11713  0.297954
# 5703             4.55                24791       270150  0.373771
# 10547            4.54                21628       267622  0.373771

# %%
semantic_search("leadership skills for new managers", 5)
# Out:
#                                             course_title  \
# 8611   New Manager: The Basics and More of Being a Gr...
# 15551  New Manager: The Basics and More of Being a Gr...
# 25505  New Manager: The Basics and More of Being a Gr...
# 8610   New Manager: The Basics and More of Being a Gr...
# 15550  New Manager: The Basics and More of Being a Gr...
#
#                       category subcategory  avg_rating_90d  \
# 8611   Leadership & Management  Leadership            4.56
# 15551  Leadership & Management  Leadership            4.57
# 25505  Leadership & Management  Leadership            4.57
# 8610   Leadership & Management  Leadership            4.56
# 15550  Leadership & Management  Leadership            4.57
#
#        num_rating_all_time  enrollments     score
# 8611                 13200       320340  0.463874
# 15551                 9511       333293  0.463874
# 25505                12854       324833  0.463874
# 8610                 13200       320340  0.510928
# 15550                 9511       333293  0.510928

# %%
semantic_search("AWS certification beginner", 5)
# Out:
#                                             course_title         category  \
# 2462   AWS Certified Cloud Practitioner - Essentials ...    IT Operations
# 19283  AWS Certified Cloud Practitioner - Essentials ...    IT Operations
# 2463   AWS Certified Cloud Practitioner - Essentials ...  Cloud Computing
# 19282  AWS Certified Cloud Practitioner - Essentials ...  Cloud Computing
# 2644   AWS Certified Developer Associate Exam Trainin...    IT Operations
#
#                 subcategory  avg_rating_90d  num_rating_all_time  enrollments  \
# 2462      IT Certifications            4.47                 1295        29952
# 19283     IT Certifications            4.50                 1253        30062
# 2463   Cloud Certifications            4.47                 1295        29952
# 19282  Cloud Certifications            4.50                 1253        30062
# 2644      IT Certifications            4.61                 3678        78867
#
#           score
# 2462   0.466187
# 19283  0.466187
# 2463   0.480968
# 19282  0.480968
# 2644   0.507188

# %%
def pretty_search(query_text, k=10):
    results = semantic_search(query_text, k)
    print(f"\nTop {k} semantic matches for query: '{query_text}'\n")
    
    display(results[['course_title', 'category', 'subcategory',
                     'avg_rating_90d', 'num_rating_all_time', 'enrollments']])

# %%
pretty_search("python for data analysis", 5)
pretty_search("presentation skills for managers", 5)
pretty_search("sql analytics", 5)
# Out:
# Top 5 semantic matches for query: 'python for data analysis'
#                                             course_title      category  \
# 375             Python for Data Analysis & Visualization   Development
# 17212           Python for Data Analysis & Visualization   Development
# 8703   Learning Python for Data Analysis and Visualiz...   Development
# 8702   Learning Python for Data Analysis and Visualiz...   Development
# 1668                           Data Analysis with Python  Data Science
#
#                  subcategory  avg_rating_90d  num_rating_all_time  enrollments
# 375    Programming Languages            4.56                 1261         5345
# 17212  Programming Languages            4.55                 1169         5445
# 8703   Programming Languages            4.32                19558        46772
# 8702   Programming Languages            4.32                19558        46772
# 1668    Statistical Analysis            4.28                  437        18984
# Top 5 semantic matches for query: 'presentation skills for managers'
#                                             course_title  \
# 15941  Presentation Skills: Give a Great Team Present...
# 10652  Presentation Skills: Give More Powerful, Memor...
# 10650  Presentation Skills: Give More Powerful, Memor...
# 15942  Presentation Skills: Give a Great Team Present...
# 10653  Presentation Skills: Give More Powerful, Memor...
#
#                       category    subcategory  avg_rating_90d  \
# 15941  Leadership & Management  Communication            4.50
# 10652  Leadership & Management  Communication            4.63
# 10650  Leadership & Management  Communication            4.63
# 15942                 Business  Communication            4.50
# 10653                 Business  Communication            4.63
#
#        num_rating_all_time  enrollments
# 15941                 3107        38677
# 10652                 6431       269736
# 10650                 6431       269736
# 15942                 3107        38677
# 10653                 6431       269736
# Top 5 semantic matches for query: 'sql analytics'
#                                             course_title      category  \
# 5652   SQL - MySQL for Data Analytics and Business In...   Development
# 10427  SQL - MySQL for Data Analytics and Business In...   Development
# 22506  SQL - MySQL for Data Analytics and Business In...   Development
# 3419   SQL for Data Analysis: Beginner MySQL Business...  Data Science
# 20238  SQL for Data Analysis: Beginner MySQL Business...  Data Science
#
#                          subcategory  avg_rating_90d  num_rating_all_time  \
# 5652   Database Design & Development            4.58                56337
# 10427  Database Design & Development            4.60                46532
# 22506  Database Design & Development            4.59                55531
# 3419                       Analytics            4.66                 8775
# 20238                      Analytics            4.64                 8665
#
#        enrollments
# 5652        682390
# 10427       680584
# 22506       686285
# 3419        216082
# 20238       217066
